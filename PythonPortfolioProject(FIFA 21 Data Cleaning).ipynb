# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Vasilis\Downloads\fifa21_raw_data.csv')
# Out:
# C:\Users\Vasilis\AppData\Local\Temp\ipykernel_13072\1084750219.py:1: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\Vasilis\Downloads\fifa21_raw_data.csv')

# %%
df
# Out:
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# 2      https://cdn.sofifa.com/players/200/389/21_60.png
# 3      https://cdn.sofifa.com/players/192/985/21_60.png
# 4      https://cdn.sofifa.com/players/190/871/21_60.png
# ...                                                 ...
# 18974  https://cdn.sofifa.com/players/257/710/21_60.png
# 18975  https://cdn.sofifa.com/players/258/736/21_60.png
# 18976  https://cdn.sofifa.com/players/247/223/21_60.png
# 18977  https://cdn.sofifa.com/players/258/760/21_60.png
# 18978  https://cdn.sofifa.com/players/255/958/21_60.png
#
#                            LongName  \
# 0                      Lionel Messi
# 1      C. Ronaldo dos Santos Aveiro
# 2                         Jan Oblak
# 3                   Kevin De Bruyne
# 4        Neymar da Silva Santos Jr.
# ...                             ...
# ...

# %%
df.drop(['photoUrl', 'playerUrl', 'Hits'], axis=1, inplace=True)
df
# Out:
#                            LongName Nationality Positions               Name  \
# 0                      Lionel Messi   Argentina  RW ST CF           L. Messi
# 1      C. Ronaldo dos Santos Aveiro    Portugal     ST LW  Cristiano Ronaldo
# 2                         Jan Oblak    Slovenia        GK           J. Oblak
# 3                   Kevin De Bruyne     Belgium    CAM CM       K. De Bruyne
# 4        Neymar da Silva Santos Jr.      Brazil    LW CAM          Neymar Jr
# ...                             ...         ...       ...                ...
# 18974                Mengxuan Zhang    China PR        CB     Zhang Mengxuan
# 18975                 Vani Da Silva     England        ST        V. Da Silva
# 18976                        Ao Xia    China PR        CB             Xia Ao
# 18977                     Ben Hough     England        CM           B. Hough
# 18978                  Mateo Flores     Bolivia       CDM          M. Flores
#
# ...

# %%
df['Team & Contract'].str.strip()
# Out:
# 0                               FC Barcelona\n2004 ~ 2021
# 1                                   Juventus\n2018 ~ 2022
# 2                            Atlético Madrid\n2014 ~ 2023
# 3                            Manchester City\n2015 ~ 2023
# 4                        Paris Saint-Germain\n2017 ~ 2022
#                                ...
# 18974    Chongqing Dangdai Lifan FC SWM Team\n2020 ~ 2020
# 18975                        Oldham Athletic\n2020 ~ 2021
# 18976                             Wuhan Zall\n2018 ~ 2022
# 18977                        Oldham Athletic\n2020 ~ 2021
# 18978                           Club Bolívar\n2020 ~ 2024
# Name: Team & Contract, Length: 18979, dtype: object

# %%
df['Team & Contract'] = df['Team & Contract'].str.strip()
df[['Team', 'Contract']] = df['Team & Contract'].str.split('\n', expand=True)
df
# Out:
#                            LongName Nationality Positions               Name  \
# 0                      Lionel Messi   Argentina  RW ST CF           L. Messi
# 1      C. Ronaldo dos Santos Aveiro    Portugal     ST LW  Cristiano Ronaldo
# 2                         Jan Oblak    Slovenia        GK           J. Oblak
# 3                   Kevin De Bruyne     Belgium    CAM CM       K. De Bruyne
# 4        Neymar da Silva Santos Jr.      Brazil    LW CAM          Neymar Jr
# ...                             ...         ...       ...                ...
# 18974                Mengxuan Zhang    China PR        CB     Zhang Mengxuan
# 18975                 Vani Da Silva     England        ST        V. Da Silva
# 18976                        Ao Xia    China PR        CB             Xia Ao
# 18977                     Ben Hough     England        CM           B. Hough
# 18978                  Mateo Flores     Bolivia       CDM          M. Flores
#
# ...

# %%
df.drop(['Team & Contract', 'LongName'], axis=1, inplace=True)
df
# Out:
#       Nationality Positions               Name  Age  ↓OVA  POT      ID Height  \
# 0       Argentina  RW ST CF           L. Messi   33    93   93  158023   5'7"
# 1        Portugal     ST LW  Cristiano Ronaldo   35    92   92   20801   6'2"
# 2        Slovenia        GK           J. Oblak   27    91   93  200389   6'2"
# 3         Belgium    CAM CM       K. De Bruyne   29    91   91  192985  5'11"
# 4          Brazil    LW CAM          Neymar Jr   28    91   91  190871   5'9"
# ...           ...       ...                ...  ...   ...  ...     ...    ...
# 18974    China PR        CB     Zhang Mengxuan   21    47   52  257710  5'10"
# 18975     England        ST        V. Da Silva   17    47   67  258736   5'7"
# 18976    China PR        CB             Xia Ao   21    47   55  247223  5'10"
# 18977     England        CM           B. Hough   17    47   67  258760   5'9"
# 18978     Bolivia       CDM          M. Flores   19    47   63  255958   5'9"
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 74 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nationality       18979 non-null  object
#  1   Positions         18979 non-null  object
#  2   Name              18979 non-null  object
#  3   Age               18979 non-null  int64
#  4   ↓OVA              18979 non-null  int64
#  5   POT               18979 non-null  int64
#  6   ID                18979 non-null  int64
#  7   Height            18979 non-null  object
#  8   Weight            18979 non-null  object
#  9   foot              18979 non-null  object
#  10  BOV               18979 non-null  int64
#  11  BP                18979 non-null  object
#  12  Growth            18979 non-null  int64
#  13  Joined            18979 non-null  object
#  14  Loan Date End     1013 non-null   object
#  15  Value             18979 non-null  object
# ...

# %%
df['Value']
# Out:
# 0        €67.5M
# 1          €46M
# 2          €75M
# 3          €87M
# 4          €90M
#           ...
# 18974      €35K
# 18975      €60K
# 18976      €40K
# 18977      €60K
# 18978      €60K
# Name: Value, Length: 18979, dtype: object

# %%
df['Value'] = df['Value'].str.strip('M').str.strip('K').str.strip('€')
df['Value'] = df['Value'].astype(float)*1000000
df['Value'].astype(int)
# Out:
# 0        67500000
# 1        46000000
# 2        75000000
# 3        87000000
# 4        90000000
#            ...
# 18974    35000000
# 18975    60000000
# 18976    40000000
# 18977    60000000
# 18978    60000000
# Name: Value, Length: 18979, dtype: int32

# %%
df['Wage']
# Out:
# 0        €560K
# 1        €220K
# 2        €125K
# 3        €370K
# 4        €270K
#          ...
# 18974      €1K
# 18975     €500
# 18976      €1K
# 18977     €500
# 18978     €500
# Name: Wage, Length: 18979, dtype: object

# %%
df['Wage'] = df['Wage'].str.strip('K').str.strip('€')
df['Wage'] = df['Wage'].astype(int)*1000
df['Wage']
# Out:
# 0        560000
# 1        220000
# 2        125000
# 3        370000
# 4        270000
#           ...
# 18974      1000
# 18975    500000
# 18976      1000
# 18977    500000
# 18978    500000
# Name: Wage, Length: 18979, dtype: int32

# %%
df['Release Clause']
# Out:
# 0        €138.4M
# 1         €75.9M
# 2        €159.4M
# 3          €161M
# 4        €166.5M
#           ...
# 18974       €57K
# 18975      €165K
# 18976       €70K
# 18977      €165K
# 18978      €167K
# Name: Release Clause, Length: 18979, dtype: object

# %%
df['Release Clause'] = df['Release Clause'].str.strip('M').str.strip('K').str.strip('€')
df['Release Clause'] = df['Release Clause'].astype(float)* 1000000
df['Release Clause'] = df['Release Clause'].astype(int)
df['Release Clause']
# Out:
# 0        138400000
# 1         75900000
# 2        159400000
# 3        161000000
# 4        166500000
#            ...
# 18974     57000000
# 18975    165000000
# 18976     70000000
# 18977    165000000
# 18978    167000000
# Name: Release Clause, Length: 18979, dtype: int32

# %%
df
# Out:
#       Nationality Positions               Name  Age  ↓OVA  POT      ID Height  \
# 0       Argentina  RW ST CF           L. Messi   33    93   93  158023   5'7"
# 1        Portugal     ST LW  Cristiano Ronaldo   35    92   92   20801   6'2"
# 2        Slovenia        GK           J. Oblak   27    91   93  200389   6'2"
# 3         Belgium    CAM CM       K. De Bruyne   29    91   91  192985  5'11"
# 4          Brazil    LW CAM          Neymar Jr   28    91   91  190871   5'9"
# ...           ...       ...                ...  ...   ...  ...     ...    ...
# 18974    China PR        CB     Zhang Mengxuan   21    47   52  257710  5'10"
# 18975     England        ST        V. Da Silva   17    47   67  258736   5'7"
# 18976    China PR        CB             Xia Ao   21    47   55  247223  5'10"
# 18977     England        CM           B. Hough   17    47   67  258760   5'9"
# 18978     Bolivia       CDM          M. Flores   19    47   63  255958   5'9"
#
# ...

# %%
cols = list(df.columns)
col_to_move = 'Team'
index = cols.index(col_to_move)
cols.insert(6, cols.pop(index))
df = df[cols]

cols = list(df.columns)
col_to_move = 'Contract'
index = cols.index(col_to_move)
cols.insert(7, cols.pop(index))
df = df[cols]

df
# Out:
#       Nationality Positions               Name  Age  ↓OVA  POT  \
# 0       Argentina  RW ST CF           L. Messi   33    93   93
# 1        Portugal     ST LW  Cristiano Ronaldo   35    92   92
# 2        Slovenia        GK           J. Oblak   27    91   93
# 3         Belgium    CAM CM       K. De Bruyne   29    91   91
# 4          Brazil    LW CAM          Neymar Jr   28    91   91
# ...           ...       ...                ...  ...   ...  ...
# 18974    China PR        CB     Zhang Mengxuan   21    47   52
# 18975     England        ST        V. Da Silva   17    47   67
# 18976    China PR        CB             Xia Ao   21    47   55
# 18977     England        CM           B. Hough   17    47   67
# 18978     Bolivia       CDM          M. Flores   19    47   63
#
#                                       Team     Contract      ID Height  ...  \
# 0                             FC Barcelona  2004 ~ 2021  158023   5'7"  ...
# ...

# %%
cols = list(df.columns)
col_to_move = 'Name'
index = cols.index(col_to_move)
cols.insert(0, cols.pop(index))
df = df[cols]

df
# Out:
#                     Name Nationality Positions  Age  ↓OVA  POT  \
# 0               L. Messi   Argentina  RW ST CF   33    93   93
# 1      Cristiano Ronaldo    Portugal     ST LW   35    92   92
# 2               J. Oblak    Slovenia        GK   27    91   93
# 3           K. De Bruyne     Belgium    CAM CM   29    91   91
# 4              Neymar Jr      Brazil    LW CAM   28    91   91
# ...                  ...         ...       ...  ...   ...  ...
# 18974     Zhang Mengxuan    China PR        CB   21    47   52
# 18975        V. Da Silva     England        ST   17    47   67
# 18976             Xia Ao    China PR        CB   21    47   55
# 18977           B. Hough     England        CM   17    47   67
# 18978          M. Flores     Bolivia       CDM   19    47   63
#
#                                       Team     Contract      ID Height  ...  \
# 0                             FC Barcelona  2004 ~ 2021  158023   5'7"  ...
# ...

# %%
df ['Contract'] = df['Contract'].str.replace('~ ', '- ')
df ['Positions'] = df['Positions'].str.replace(' ', ', ')

df
# Out:
#                     Name Nationality   Positions  Age  ↓OVA  POT  \
# 0               L. Messi   Argentina  RW, ST, CF   33    93   93
# 1      Cristiano Ronaldo    Portugal      ST, LW   35    92   92
# 2               J. Oblak    Slovenia          GK   27    91   93
# 3           K. De Bruyne     Belgium     CAM, CM   29    91   91
# 4              Neymar Jr      Brazil     LW, CAM   28    91   91
# ...                  ...         ...         ...  ...   ...  ...
# 18974     Zhang Mengxuan    China PR          CB   21    47   52
# 18975        V. Da Silva     England          ST   17    47   67
# 18976             Xia Ao    China PR          CB   21    47   55
# 18977           B. Hough     England          CM   17    47   67
# 18978          M. Flores     Bolivia         CDM   19    47   63
#
#                                       Team     Contract      ID Height  ...  \
# 0                             FC Barcelona  2004 - 2021  158023   5'7"  ...
# ...
