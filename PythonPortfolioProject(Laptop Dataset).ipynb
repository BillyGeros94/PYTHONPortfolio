# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Vasilis\Downloads\laptop_prices.csv')

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_usd         1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.describe().drop(['laptop_ID'], axis = 1)
# Out:
#             Inches    Price_usd
# count  1303.000000  1303.000000
# mean     15.017191  1236.055691
# std       1.426304   768.909947
# min      10.100000   191.400000
# 25%      14.000000   658.900000
# 50%      15.600000  1074.700000
# 75%      15.600000  1636.668000
# max      18.400000  6708.900000

# %%
df.groupby('Company').describe().drop(['laptop_ID'], axis = 1)
# Out:
#           Inches                                                             \
#            count       mean           std   min     25%    50%    75%   max
# Company
# Acer       103.0  15.063107  1.418850e+00  11.6  14.000  15.60  15.60  17.3
# Apple       21.0  13.247619  1.237182e+00  11.6  12.000  13.30  13.30  15.4
# Asus       158.0  15.450000  1.519124e+00  11.6  14.000  15.60  17.30  17.3
# Chuwi        3.0  14.500000  1.905256e+00  12.3  13.950  15.60  15.60  15.6
# Dell       297.0  15.136027  1.254592e+00  11.6  14.000  15.60  15.60  17.3
# Fujitsu      3.0  15.600000  0.000000e+00  15.6  15.600  15.60  15.60  15.6
# Google       3.0  12.300000  2.175584e-15  12.3  12.300  12.30  12.30  12.3
# HP         274.0  14.943066  1.450896e+00  11.6  14.000  15.60  15.60  17.3
# Huawei       2.0  13.000000  0.000000e+00  13.0  13.000  13.00  13.00  13.0
# LG           3.0  15.066667  9.237604e-01  14.0  14.800  15.60  15.60  15.6
# ...

# %%
df.groupby('Company')['Price_usd'].mean().sort_values(ascending = False)
# Out:
# Company
# Razer        3680.757143
# LG           2308.900000
# MSI          1901.798963
# Google       1845.433333
# Microsoft    1773.539167
# Apple        1720.618429
# Huawei       1566.400000
# Samsung      1554.788889
# Toshiba      1394.593750
# Dell         1304.675889
# Xiaomi       1246.808750
# Asus         1214.586304
# Lenovo       1195.022889
# HP           1174.552339
# Fujitsu       801.900000
# Acer          689.453408
# Chuwi         345.726333
# Mediacom      324.500000
# Vero          239.167500
# Name: Price_usd, dtype: float64

# %%
df1 = df.groupby('Company', as_index = False).agg({'Price_usd':'mean'}).sort_values(by = 'Price_usd')

plt.figure(figsize = (20,10))
sns.set_style('whitegrid')
sns.lineplot( x = 'Company', y = 'Price_usd', data = df1, marker = 'o', markersize=10, color = '#022323')
plt.title('Average Laptop Price Per Company', fontsize=14, fontweight='bold')
plt.xlabel('Company')
plt.ylabel('Price (USD)')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
df.groupby('TypeName')['Price_usd'].mean().sort_values()
# Out:
# TypeName
# Netbook                699.855200
# Notebook               860.286487
# 2 in 1 Convertible    1410.641818
# Ultrabook             1703.053393
# Gaming                1904.518698
# Workstation           2508.394862
# Name: Price_usd, dtype: float64

# %%
df2 = df.groupby('TypeName', as_index = False).agg({'Price_usd':'mean'}).sort_values(by = 'Price_usd')

plt.figure(figsize = (20,10))
sns.set_style('darkgrid')
sns.barplot( x = 'TypeName', y = 'Price_usd', data = df2, color = '#ff022f')
plt.title('Average Laptop Price Per Type', fontsize=14, fontweight='bold')
plt.xlabel('Laptop Type')
plt.ylabel('Price (USD)')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
df.groupby('Ram')['Price_usd'].mean().sort_values()
# Out:
# Ram
# 2GB      279.807500
# 4GB      632.029728
# 6GB      676.726976
# 8GB     1298.894234
# 12GB    1363.382240
# 16GB    2130.448265
# 24GB    2426.966667
# 32GB    3754.394471
# 64GB    4372.500000
# Name: Price_usd, dtype: float64

# %%
df3 = df.groupby('Ram', as_index = False).agg({'Price_usd':'mean'})
df3['Ram'] = df3['Ram'].str.replace('GB', '').astype(int)

plt.figure(figsize = (20,10))
sns.set_style('white')
sns.pointplot( x = 'Ram', y = 'Price_usd', data = df3,color = '#5e6667')
plt.title('Average Laptop Price Per Ram Capacity', fontsize=14, fontweight='bold')
plt.xlabel('Ram (GB)')
plt.ylabel('Price (USD)')
# Out:
# Text(0, 0.5, 'Price (USD)')

# %%
df.groupby('OpSys')['Price_usd'].mean().sort_values()
# Out:
# OpSys
# Android          477.400000
# Chrome OS        608.943704
# No OS            646.770667
# Linux            678.775758
# Windows 10      1284.953425
# Mac OS X        1389.158375
# Windows 10 S    1415.128000
# Windows 7       1855.316467
# macOS           1924.593846
# Name: Price_usd, dtype: float64

# %%
df4 = df.groupby('OpSys', as_index = False).agg({'Price_usd':'mean'}).sort_values(by = 'Price_usd')

plt.figure(figsize = (20,10))
sns.set_style('dark')
sns.barplot( x = 'Price_usd', y = 'OpSys', data = df4, color = '#156062')
plt.title('Average Laptop Price Per Operating System', fontsize=14, fontweight='bold')
plt.xlabel('Price (USD)')
plt.ylabel('Operating System')
# Out:
# Text(0, 0.5, 'Operating System')
